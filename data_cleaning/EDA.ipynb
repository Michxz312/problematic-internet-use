# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in dataframe that contains raw data
df = pd.read_csv('../raw_data/train.csv')

# %%
# remove any columns that have 'stat' in them - most of these values are missing,
# aren't well described, and so will be difficult to interpret
df = df[df.columns.drop(list(df.filter(regex='stat')))]
# save the dataframe
df.to_csv('../raw_data/start_here.csv')

# %%
# look at the shape of the resulting dataframe
df.shape
# Out:
# (2736, 59)

# %%
# make a plot of the response variable ('sii'), which indicates problematic internet
# usage

# set plot style
sns.set_style("whitegrid")
# basic plot arguments
ax = sns.countplot(data=df, x = 'sii', hue='sii', legend = False)
# axis labels and title
plt.xlabel('PCIAT Score')
plt.ylabel('Number of participants')
plt.title('Number of participants grouped by score on PCIAT test')
# put counts above each bar
for i in ax.containers:
    ax.bar_label(i,)
# show the plot
plt.show()
# clear plot field for any future plotting
plt.clf()
